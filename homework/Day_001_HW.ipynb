# %% [markdown]
# 作業1：
# House Prices: Advanced Regression Techniques
# https://www.kaggle.com/c/house-prices-advanced-regression-techniques
#
# 1. 你選的這組資料為何重要
# 如果可以知道房價變異的因數，公部門就可以施行適當的政策來穩定房價。
# 用來預測房價，裡面的79種變數，研究成果價格取決於房間數及有沒有白欄杆
#
# 2. 資料從何而來 (tips: 譬如提供者是誰、以什麼方式蒐集)
# 實際搜集
# The Ames Housing dataset was compiled by Dean De Cock
# Truman State University
# 2006 to 2010
#
# 3. 蒐集而來的資料型態為何
# 結構化表格資料
# 所有房子的屬性，包含游泳池，屋頂類型等
#
# 4. 這組資料想解決的問題如何評估
# 找出跟房價高低較有相關的幾個因素
# 想解決房價的價格是否有什麼相關性

# %% [markdown]
# 作業2：
#
# 想像你經營一個自由載客車隊，你希望能透過數據分析以提升業績，請你思考並描述你如何規劃整體的分析/解決方案：
#
# 1. 核心問題為何 (tips：如何定義 「提升業績 & 你的假設」)
# 減少空車時間，讓所有司機都能維持載客狀態越久越好，司機就賺更多錢，公司也抽更多
#
# 2. 資料從何而來 (tips：哪些資料可能會對你想問的問題產生影響 & 資料如何蒐集)
# 實際司機載客資料
#
# 3. 蒐集而來的資料型態為何
# 結構化的資料
# 車型，載客地點，下客地點，時間，司機評價
#
# 4. 你要回答的問題，其如何評估 (tips：你的假設如何驗證)
# 空車時間減少

# %% [markdown]
# ## 練習時間
# #### 請寫一個函式用來計算 Mean Square Error
# $ MSE = \frac{1}{n}\sum_{i=1}^{n}{(Y_i - \hat{Y}_i)^2} $
#
# ### Hint: [如何取平方](https://googoodesign.gitbooks.io/-ezpython/unit-1.html)

# %%
import numpy as np
import matplotlib.pyplot as plt

# %%
#標準差
def mean_squared_error(y,y_basement):
    """
    請完成這個 Function 後往下執行
    """
    mse = sum((y - y_basement) ** 2) / len(y)
    return mse
#平均絕對誤差    
def mean_absolute_error(y, yp):
    """
    計算 MAE
    Args:
        - y: 實際值
        - yp: 預測值
    Return:
        - mae: MAE
    """
    mae = MAE = sum(abs(y - yp)) / len(y)
    return mae

# %%
w = 3
b = 0.5

x_lin = np.linspace(0, 100, 101)

y = (x_lin + np.random.randn(101) * 5) * w + b

plt.plot(x_lin, y, 'b.', label = 'data points')
plt.title("Assume we have data points")
plt.legend(loc = 2)
plt.show()

# %%
y_hat = x_lin * w + b
plt.plot(x_lin, y, 'b.', label = 'data')
plt.plot(x_lin, y_hat, 'r-', label = 'prediction')
plt.title("Assume we have data points (And the prediction)")
plt.legend(loc = 2)
plt.show()

# %%
# 執行 Function, 確認有沒有正常執行
MSE = mean_squared_error(y, y_hat)
MAE = mean_absolute_error(y, y_hat)
print("The Mean squared error is %.3f" % (MSE))
print("The Mean absolute error is %.3f" % (MAE))
# Out:
# The Mean squared error is 242.246
# The Mean absolute error is 12.308
